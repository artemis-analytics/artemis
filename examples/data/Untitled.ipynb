# %%
import pandas as pd

# %%
product = pd.read_excel("example_product.xlsx")
template = pd.read_excel("template.xlsx")
metastore = pd.read_excel("Dataset_metastore.xlsx")

# %%
product
# Out:
#        Dataset Metadata                                   Unnamed: 1  \
# 0         Metadata Name                                          NaN
# 1          Data Holding                                 Dataset Name
# 2                   NaN                                  Description
# 3                   NaN                              Program Element
# 4                   NaN        Has Sensitive Statistical Info? [y/n]
# 5                   NaN              Has Personal Identifiers? [y/n]
# 6                   NaN    Has Other Supporting Documentation? [y/n]
# 7                   NaN                      List of Expected Medium
# 8                   NaN                                List of Usage
# 9                   NaN                                   Permission
# 10                  NaN                                     Provider
# 11                  NaN  Provider Type [External/Internal/Custodian]
# 12           Data Asset                                  Description
# ...

# %%
template
# Out:
#        Dataset Metadata                                   Unnamed: 1  \
# 0         Metadata Name                                          NaN
# 1          Data Holding                                 Dataset Name
# 2                   NaN                                  Description
# 3                   NaN                              Program Element
# 4                   NaN        Has Sensitive Statistical Info? [y/n]
# 5                   NaN              Has Personal Identifiers? [y/n]
# 6                   NaN    Has Other Supporting Documentation? [y/n]
# 7                   NaN                      List of Expected Medium
# 8                   NaN                                List of Usage
# 9                   NaN                                   Permission
# 10                  NaN                                     Provider
# 11                  NaN  Provider Type [External/Internal/Custodian]
# 12           Data Asset                                  Description
# ...

# %%
metastore
# Out:
#        Dataset Metadata                                   Unnamed: 1  \
# 0         Metadata Name                                          NaN
# 1          Data Holding                                 Dataset Name
# 2                   NaN                                  Description
# 3                   NaN                              Program Element
# 4                   NaN        Has Sensitive Statistical Info? [y/n]
# 5                   NaN              Has Personal Identifiers? [y/n]
# 6                   NaN    Has Other Supporting Documentation? [y/n]
# 7                   NaN                      List of Expected Medium
# 8                   NaN                                List of Usage
# 9                   NaN                                   Permission
# 10                  NaN                                     Provider
# 11                  NaN  Provider Type [External/Internal/Custodian]
# 12           Data Asset                                  Description
# ...
